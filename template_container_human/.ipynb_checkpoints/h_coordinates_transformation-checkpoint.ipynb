# %%
#human
import numpy as np
#create a list of all names used
#names are saved in fale names, variable names
from events import RGB_TO_ACR, ACR_TO_PARENT
names = []
for v in RGB_TO_ACR:
    temp = [v, RGB_TO_ACR[v]]
    if RGB_TO_ACR[v] in ACR_TO_PARENT:
        temp.append(ACR_TO_PARENT[RGB_TO_ACR[v]]) 
    names.append(temp)

#create a list of areas available for labels
parent_labels = []
for i in range(len(names)):
    k = len(names[i])
    parent_labels.append(names[i][k-1]) 
parent_labels1 = np.array(parent_labels) # parent_labels1 ia a list of all available parent labels in this atlas

print (np.unique(parent_labels1))
# Out:
# ['3rd Ventricle' '4th Ventricle' '5th Ventricle' 'ACgG (L)' 'ACgG (R)'
#  'AIns (R)' 'AIns, left' 'AOrG (L)' 'AOrG (R)' 'Accumbens Area (L)'
#  'Accumbens Area (R)' 'Amygdala (L)' 'Amygdala (R)' 'AnG (L)' 'AnG (R)'
#  'Basal Forebrain (L)' 'Basal Forebrain (R)' 'Brain Stem' 'CO (L)'
#  'CO (R)' 'CSF' 'CYAN' 'Calc (L)' 'Calc (R)' 'Caudate (L)' 'Caudate (R)'
#  'Cerebellar Vermal Lobules I-V' 'Cerebellar Vermal Lobules VI-VII'
#  'Cerebellar Vermal Lobules VIII-X' 'Cerebellum Exterior (L)'
#  'Cerebellum Exterior (R)' 'Cerebellum White Matter (L)'
#  'Cerebellum White Matter (R)' 'Cerebral Exterior (L)'
#  'Cerebral Exterior (R)' 'Cerebral White Matter (L)'
#  'Cerebral White Matter (R)' 'CgG (L)' 'CgG (R)' 'Cun (L)' 'Cun (R)'
#  'Ent (L)' 'Ent (R)' 'FO (L)' 'FO (R)' 'FRP (L)' 'FRP (R)' 'FuG (L)'
#  'FuG (R)' 'GRe (L)' 'GRe (R)' 'Heschls' 'Hippocampus (L)'
#  'Hippocampus (R)' 'IOG (L)' 'IOG (R)' 'IOrG (L)' 'IOrG (R)' 'ITG (L)'
#  'ITG (R)' 'Inf Lat Vent (L)' 'Inf Lat Vent (R)' 'Insula (L)' 'Insula (R)'
#  'LOrG (L)' 'LOrG (R)' 'Lat Vent (L)' 'Lat Vent (R)' 'Lesion (L)'
#  'Lesion (R)' 'LiG (L)' 'LiG (R)' 'MCgG (L)' 'MCgG (R)' 'MFC (L)'
#  'MFC (R)' 'MFG (L)' 'MFG (R)' 'MOG (L)' 'MOG (R)' 'MOrG (L)' 'MOrG (R)'
#  'MPoG (L)' 'MPoG (R)' 'MPrG (L)' 'MPrG (R)' 'MSFG (L)' 'MSFG (R)'
#  'MTG (L)' 'MTG (R)' 'OCP (L)' 'OCP (R)' 'OFC (L)' 'OFC (R)' 'OFuG (L)'
#  'OFuG (R)' 'OpIFG (L)' 'OpIFG (R)' 'Operculum (L)' 'Operculum (R)'
#  'Optic Chiasm' 'OrIFG (L)' 'OrIFG (R)' 'PCgG (L)' 'PCgG (R)' 'PCu (L)'
#  'PCu (R)' 'PHG (L)' 'PHG (R)' 'PIns (L)' 'PIns (R)' 'PO (L)' 'PO (R)'
#  'POrG (L)' 'POrG (R)' 'PP (L)' 'PP (R)' 'PT (L)' 'PT (R)' 'Pallidum (L)'
#  'Pallidum (R)' 'PoG (L)' 'PoG (R)' 'PrG (L)' 'PrG (R)' 'Putamen (L)'
#  'Putamen (R)' 'RED' 'SCA (L)' 'SCA (R)' 'SCLC (L)' 'SCLC (R)' 'SFG (L)'
#  'SFG (R)' 'SMC (L)' 'SMC (R)' 'SMG (L)' 'SMG (R)' 'SOG (L)' 'SOG (R)'
#  'SPL (L)' 'SPL (R)' 'STG (L)' 'STG (R)' 'TMP (L)' 'TMP (R)' 'TTG (L)'
#  'TTG (R)' 'Thalamus Proper (L)' 'Thalamus Proper (R)' 'TrIFG (L)'
#  'TrIFG (R)' 'Unlabeled' 'Ventral DC (L)' 'Ventral DC (R)'
#  'Vitamin E Tablet' 'YELLOW' '[0]' 'aals' 'ahls' 'anterior_occipital'
#  'calcarine' 'central' 'central_insular' 'central_vermal_sulcus'
#  'cingulate' 'circular' 'collateral' 'first_transverse' 'frontomarginal'
#  'inferior_frontal' 'inferior_rostral' 'inferior_temporal'
#  'inferior_vermal_sulcus' 'intraparietal' 'lateral' 'lateral_occipital'
#  'lateral_orbital' 'lateral_vermal_sulcus' 'lhos' 'mhos' 'occ_temporal'
#  'olfactory' 'pals' 'par_occipital' 'phls' 'postcentral' 'precentral'
#  'primary_inter' 'subparietal' 'superior_frontal' 'superior_rostral'
#  'superior_temporal' 'superior_vermal_sulcus' 'thos' 'vessel (L)'
#  'vessel (R)']

# %% [markdown]
# # Create file variables.py to collect all paths for each slice separately

# %%
#human
#create list of events on each slice
from template_container_human import SVG_PATHS, BRAIN_REGIONS, BRAIN_SLICES
events = []
for key in BRAIN_REGIONS:
    val = BRAIN_REGIONS[key]
    slices = val.keys()
    for item in slices:
        events.append([key, item])
print (len(events))
print(events[:10])
# Out:
# 5337
# [['01EE00', '0'], ['01EE00', '1'], ['01EE00', '2'], ['01EE00', '3'], ['01EE00', '4'], ['01EE00', '5'], ['01EE00', '6'], ['01EE00', '7'], ['01EE00', '8'], ['01EE00', '9']]

# %%
#add to file variables.py (slice#)_paths = events that can be present on each slice
ev_to_apply = []
for j in range(0,179):
    ev_to_apply.append([j])
    for i in range(len(events)):
        if str(j) == str(events[i][1]):
            ev_to_apply[j].append(events[i][0])
f0 = open("variables.py","a")
f0.write('events_by_slices=' +str(tuple(ev_to_apply))+' \n')
f0.close()
print((ev_to_apply[0]))
print((ev_to_apply[1]))
print((ev_to_apply[2]))
print((ev_to_apply[3]))
print((ev_to_apply[4]))
print((ev_to_apply[5]))
# Out:
# [0, '01EE00']
# [1, '01EE00']
# [2, '01EE00', '00EE00']
# [3, '01EE00', '00EE00', 'E0E1E1']
# [4, '01EE00', '00EE00', 'E0E1E1']
# [5, '01EE00', '00EE00', 'E0E1E1']

# %%
# create a list of paths for each slice

f1 = open('variables.py', 'a')
for i in range(len(ev_to_apply)):
    f1.write('slice_'+str(i)+'_paths={')
    for j in range(1, len(ev_to_apply[i])):
        ev = ev_to_apply[i][j]
        path = BRAIN_REGIONS[ev]
        if str(ev_to_apply[i][0]) in path:
            f1.write('"'+str(ev_to_apply[i][j])+'"'+':'+str(path[str(i)])+(', '))
    f1.write('} \n')
f1.close()

# %%
f0.close()
f1.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dcf10ff0f1ab> in <module>
#       1 f0.close()
# ----> 2 f1.close()
#
# NameError: name 'f1' is not defined

# %%
# add to file variables.py paths_by_slices = [[{event:paths}], ...]
# 0 item in the list is for 0 slice and so on.
paths_by_slices = []

for i in range(len(ev_to_apply)):
    paths_by_slices.append([])
    for j in range(1, len(ev_to_apply[i])):
        ev = ev_to_apply[i][j]
        path = BRAIN_REGIONS[ev]
        if str(ev_to_apply[i][0]) in path:
            paths_by_slices[i].append(tuple(path[str(i)]))
f2 = open('variables.py', 'a')
f2.write('paths_by_slices = '+str(tuple(paths_by_slices))+'\n')
f2.close()

# %%
f2.close()

# %% [markdown]
# # Transform .svg coordinates to pixel coordinates

# %%
#just for the test
#create proper some of the labels for the template #106 and save as .png in labels folder
templ_106 = [106, '771286', '781286', 'CD3E4E', 'ED0000', 
             'EE0000', 'CF2090']
#create the list of paths for the template 94
list_of_paths = []
for i in range(1, len(templ_106)):
    x = BRAIN_REGIONS[templ_106[i]]
    y = x['106']
    list_of_paths.append(y)
#change the list_of_paths from list of lists to list of numbers
unlisted = []
for i in range(len(list_of_paths)):
    for j in range(len(list_of_paths[i])):
        unlisted.append(list_of_paths[i][j])

# %%
import os
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
from PIL import Image

#transform SVG paths to .png and then to pixel coordinates

#indexes of pathes to be used for the template 94 are stored in variable unlisted
labels = []
for i in range(len(list_of_paths)):
    f = open("transform.svg","w+")
    f.write('<svg  width="13200" height="10800" xmlns="http://www.w3.org/2000/svg"> \n')
    for j in range(len(list_of_paths[i])):
        f.write('    <path d="'+SVG_PATHS[list_of_paths[i][j]]+'" stroke="red" fill="red"/> \n')
    f.write('</svg>') 
    f.close() 
    drawing = svg2rlg("transform.svg")
    renderPM.drawToFile(drawing, "labels/13"+str(i)+".png", fmt="PNG") 
    r = Image.open("labels/13"+str(i)+".png")
    r1=r.resize((168,137), Image.LANCZOS)
    r1.save("labels/r.png", 'PNG')
    r2 = Image.open('labels/r.png')
    r3=Image.new('RGBA', (256, 256), (0, 0, 0, 255))
    r3.paste(r2,(55, 60))
    r3.save("labels/"+str(i)+".png", 'PNG')
    r.close()
    r2.close()
    os.remove("labels/13"+str(i)+".png")
    os.remove("labels/r.png")
    coordinates = []
    width, height = r3.size
    for x in range(width):
        for y in range(height):
            r,g,b,a = r3.getpixel((x,y))
            if r==255 and g==b==0:
                coordinates.append((x,y))
    labels.append(tuple(coordinates))
    r3.close
    os.remove("labels/"+str(i)+".png")
print(len(labels))
print(len(labels[1]))
# Out:
# 6
# 109

# %%
r.close()

# %%
#test if converted pixel coordinates correspond to the real label (white matter, slice(176))
from PIL import ImageFilter
im = Image.new('RGBA', (256, 256), (0, 0, 0, 0))
for i in range(len(labels[5])):
    pixel=labels[5][i]
    pixel_w=int(pixel[0])
    pixel_h=int(pixel[1])
    im.putpixel(pixel, (255,0,0,255))
im = im.filter(ImageFilter.GaussianBlur(radius=1))
im.save('labels/im.png', 'PNG')

# %% [markdown]
# # create .py file: labels.py in a container folder

# %%
#human
import os
from template_container_human import SVG_PATHS
import time
from variables import events_by_slices, paths_by_slices
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
from PIL import Image
start_time = time.time()

for i in range(len(paths_by_slices)):
    labels_coordinates = open('labels/slice_'+str(events_by_slices[i][0])+'.py', 'a')
    for j in range(len(paths_by_slices[i])):
        paths_pos = paths_by_slices[i][j]
        labels_coordinates.write('coordinates_'+str(events_by_slices[i][j+1])+' = (')
        f = open("transform.svg","w+")
        f.write('<svg  width="13200" height="10800" xmlns="http://www.w3.org/2000/svg"> \n')
        for k in range(len(paths_pos)):
            f.write('    <path d="'+SVG_PATHS[paths_pos[k]]+'" stroke="red" fill="red"/> \n')
        f.write('</svg>') 
        f.close() 
        drawing = svg2rlg("transform.svg")
        renderPM.drawToFile(drawing, "labels/temp"+str(i)+".png", fmt="PNG") 
        r = Image.open("labels/temp"+str(i)+".png")
        r1=r.resize((168,137), Image.LANCZOS)
        r1.save("labels/r.png", 'PNG')
        r2 = Image.open('labels/r.png')
        r3=Image.new('RGBA', (256, 256), (0, 0, 0, 255))
        r3.paste(r2,(55, 60))
        r3.save("labels/"+str(i)+".png", 'PNG')
        r.close()
        r2.close()
        os.remove("labels/temp"+str(i)+".png")
        os.remove("labels/r.png")
        coordinates = []
        width, height = r3.size
        m=0
        for x in range(width):
            for y in range(height):
                r,g,b,a = r3.getpixel((x,y))
                if r==255 and g==b==0:
                    m = m+1
                    coordinates.append((x,y))
        t = tuple(coordinates)
        for a in range(len(t)):
            labels_coordinates.write(str(t[a])+', ')
            if a%72 == 0:
                labels_coordinates.write(" \n")
        labels_coordinates.write(") \n")
        r3.close
        os.remove("labels/"+str(i)+".png")
    labels_coordinates.close()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---
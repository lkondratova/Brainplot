# %%
import numpy as np
#create a list of all names used
#names are saved in fale names, variable names
from events import RGB_TO_ACR, ACR_TO_PARENT
names = []
for v in RGB_TO_ACR:
    temp = [v, RGB_TO_ACR[v]]
    if RGB_TO_ACR[v] in ACR_TO_PARENT:
        temp.append(ACR_TO_PARENT[RGB_TO_ACR[v]]) 
    names.append(temp)

#create a list of areas available for labels
parent_labels = []
for i in range(len(names)):
    k = len(names[i])
    parent_labels.append(names[i][k-1]) 
parent_labels1 = np.array(parent_labels) # parent_labels1 ia a list of all available parent labels in this atlas

print (np.unique(parent_labels1))
# Out:
# ['central subpallium' 'cerebellum' 'cingulate cortex' 'diencephalon'
#  'dorsal pallium' 'forebrain' 'frontal cortex' 'hindbrain' 'hippocampus'
#  'hypothalamus' 'insular cortex' 'isocortex' 'lateral pallium'
#  'medial pallium' 'medulla' 'metencephalon' 'midbrain' 'myelencephalon'
#  'occipital cortex' 'orbitofrontal cortex' 'p2' 'pallidum' 'pallium'
#  'paraseptal subpallium' 'parietal cortex' 'pons'
#  'secondary prosencephalon' 'striatum' 'subpallial amygdala'
#  'subpallial septum' 'subpallium' 'telencephalon' 'temporal cortex'
#  'thalamus' 'ventral pallium' 'ventricles' 'white matter']

# %% [markdown]
# parent_labels = ['central subpallium' 'cerebellum' 'cingulate cortex' 'diencephalon'
#  'dorsal pallium' 'forebrain' 'frontal cortex' 'hindbrain' 'hippocampus'
#  'hypothalamus' 'insular cortex' 'isocortex' 'lateral pallium'
#  'medial pallium' 'medulla' 'metencephalon' 'midbrain' 'myelencephalon'
#  'occipital cortex' 'orbitofrontal cortex' 'p2' 'pallidum' 'pallium'
#  'paraseptal subpallium' 'parietal cortex' 'pons'
#  'secondary prosencephalon' 'striatum' 'subpallial amygdala'
#  'subpallial septum' 'subpallium' 'telencephalon' 'temporal cortex'
#  'thalamus' 'ventral pallium' 'ventricles' 'white matter']

# %% [markdown]
# # Create file variables.py to collect all paths for each slice separately

# %%
#create list of events on each slice
from template_container_macaque import SVG_PATHS, BRAIN_REGIONS, BRAIN_SLICES
events = []
for key in BRAIN_REGIONS:
    val = BRAIN_REGIONS[key]
    slices = val.keys()
    for item in slices:
        events.append([key, item])
print (len(events))
print(events[:10])
# Out:
# 4267
# [['FF0061', '0'], ['FF0061', '1'], ['FF0061', '2'], ['FF0061', '3'], ['FF0061', '4'], ['7F0030', '5'], ['7F0030', '6'], ['7F0030', '7'], ['7F0030', '8'], ['7F0030', '9']]

# %%
#add to file variables.py (slice#)_paths = events that can be present on each slice
ev_to_apply = []
for j in range(0,158):
    ev_to_apply.append([j])
    for i in range(len(events)):
        if str(j) == str(events[i][1]):
            ev_to_apply[j].append(events[i][0])
f0 = open("variables.py","a")
f0.write('events_by_slices=' +str(tuple(ev_to_apply))+' \n')
f0.close
print((ev_to_apply[0]))
print((ev_to_apply[1]))
print((ev_to_apply[2]))
print((ev_to_apply[3]))
print((ev_to_apply[4]))
print((ev_to_apply[5]))
# Out:
# [0, 'FF0061']
# [1, 'FF0061']
# [2, 'FF0061']
# [3, 'FF0061']
# [4, 'FF0061']
# [5, '7F0030', 'FF00E1', '006B7F', '00EBFF', '00FF92', '7F0070']

# %%
# create a list of paths for each slice

f1 = open('variables.py', 'a')
for i in range(len(ev_to_apply)):
    f1.write('slice_'+str(i)+'_paths={')
    for j in range(1, len(ev_to_apply[i])):
        ev = ev_to_apply[i][j]
        path = BRAIN_REGIONS[ev]
        if str(ev_to_apply[i][0]) in path:
            f1.write('"'+str(ev_to_apply[i][j])+'"'+':'+str(path[str(i)])+(', '))
    f1.write('} \n')
f1.close()

# %%
# add to file variables.py paths_by_slices = [[{event:paths}], ...]
# 0 item in the list is for 0 slice and so on.
paths_by_slices = []

for i in range(len(ev_to_apply)):
    paths_by_slices.append([])
    for j in range(1, len(ev_to_apply[i])):
        ev = ev_to_apply[i][j]
        path = BRAIN_REGIONS[ev]
        if str(ev_to_apply[i][0]) in path:
            paths_by_slices[i].append(tuple(path[str(i)]))
f2 = open('variables.py', 'a')
f2.write('paths_by_slices = '+str(tuple(paths_by_slices))+'\n')
f2.close()

# %% [markdown]
# # Transform .svg coordinates to pixel coordinates

# %%
#just for the test
#create proper labels for the template #106 and save as .png in labels folder
templ_106 = [106, '00EBFF', '00007F', '7F5300']
#create the list of paths for the template 94
list_of_paths = []
for i in range(1, len(templ_106)):
    x = BRAIN_REGIONS[templ_106[i]]
    y = x['106']
    list_of_paths.append(y)
#change the list_of_paths from list of lists to list of numbers
unlisted = []
for i in range(len(list_of_paths)):
    for j in range(len(list_of_paths[i])):
        unlisted.append(list_of_paths[i][j])

# %%
import os
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
from PIL import Image

#transform SVG paths to .png and then to pixel coordinates

#indexes of pathes to be used for the template 94 are stored in variable unlisted
labels = []
for i in range(len(list_of_paths)):
    f = open("transform.svg","w+")
    f.write('<svg  width="13200" height="10800" xmlns="http://www.w3.org/2000/svg"> \n')
    for j in range(len(list_of_paths[i])):
        f.write('    <path d="'+SVG_PATHS[list_of_paths[i][j]]+'" stroke="red" fill="red"/> \n')
    f.write('</svg>') 
    f.close() 
    drawing = svg2rlg("transform.svg")
    renderPM.drawToFile(drawing, "labels/13"+str(i)+".png", fmt="PNG") 
    r = Image.open("labels/13"+str(i)+".png")
    r1=r.resize((388,318), Image.LANCZOS)
    r1.save("labels/r.png", 'PNG')
    r2 = Image.open('labels/r.png')
    r3=Image.new('RGBA', (400, 340), (0, 0, 0, 255))
    r3.paste(r2,(19, 35))
    r3.save("labels/"+str(i)+".png", 'PNG')
    r.close()
    r2.close()
    os.remove("labels/13"+str(i)+".png")
    os.remove("labels/r.png")
    coordinates = []
    width, height = r3.size
    for x in range(width):
        for y in range(height):
            r,g,b,a = r3.getpixel((x,y))
            if r==255 and g==b==0:
                coordinates.append((x,y))
    labels.append(tuple(coordinates))
    r3.close
    os.remove("labels/"+str(i)+".png")
print(len(labels))
print(len(labels[1]))
# Out:
# 3
# 215

# %%
#test if converted pixel coordinates correspond to the real label (white matter, slice(176))
from PIL import ImageFilter
im = Image.new('RGBA', (407, 353), (0, 0, 0, 0))
for i in range(len(labels[0])):
    pixel=labels[0][i]
    pixel_w=int(pixel[0])
    pixel_h=int(pixel[1])
    im.putpixel(pixel, (255,0,0,255))
im = im.filter(ImageFilter.GaussianBlur(radius=2))
im.save('labels/im.png', 'PNG')

# %% [markdown]
# # create .py file: labels.py in a container folder

# %%
#macaque
import os
from template_container_macaque import SVG_PATHS
import time
from variables import events_by_slices, paths_by_slices
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
from PIL import Image
start_time = time.time()

for i in range(len(paths_by_slices)):
    labels_coordinates = open('labels/slice_'+str(events_by_slices[i][0])+'.py', 'a')
    for j in range(len(paths_by_slices[i])):
        paths_pos = paths_by_slices[i][j]
        labels_coordinates.write('coordinates_'+str(events_by_slices[i][j+1])+' = (')
        f = open("transform.svg","w+")
        f.write('<svg  width="13200" height="10800" xmlns="http://www.w3.org/2000/svg"> \n')
        for k in range(len(paths_pos)):
            f.write('    <path d="'+SVG_PATHS[paths_pos[k]]+'" stroke="red" fill="red"/> \n')
        f.write('</svg>') 
        f.close() 
        drawing = svg2rlg("transform.svg")
        renderPM.drawToFile(drawing, "labels/temp"+str(i)+".png", fmt="PNG") 
        r = Image.open("labels/temp"+str(i)+".png")
        r1=r.resize((388,318), Image.LANCZOS)
        r1.save("labels/r.png", 'PNG')
        r2 = Image.open('labels/r.png')
        r3=Image.new('RGBA', (400, 340), (0, 0, 0, 255))
        r3.paste(r2,(19, 35))
        r3.save("labels/"+str(i)+".png", 'PNG')
        r.close()
        r2.close()
        os.remove("labels/temp"+str(i)+".png")
        os.remove("labels/r.png")
        coordinates = []
        width, height = r3.size
        m=0
        for x in range(width):
            for y in range(height):
                r,g,b,a = r3.getpixel((x,y))
                if r==255 and g==b==0:
                    m = m+1
                    coordinates.append((x,y))
        t = tuple(coordinates)
        for a in range(len(t)):
            labels_coordinates.write(str(t[a])+', ')
            if a%72 == 0:
                labels_coordinates.write(" \n")
        labels_coordinates.write(") \n")
        r3.close
        os.remove("labels/"+str(i)+".png")
    labels_coordinates.close()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# C:\Users\Liudmyla\Anaconda3\lib\site-packages\PIL\Image.py:2731: DecompressionBombWarning: Image size (142560000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# --- 29069.417461156845 seconds ---

# %%
labels_coordinates.close()
r.close()

# %%
from variables import paths_by_slices

# %%
#dictionalry to create corresponding slices' names
list_1 = []
slices_numbers = {}
i = 494
for k in range(0, 158):
    slices_numbers[i] = k
    i = i-3
print(slices_numbers)
# Out:
# {494: 0, 491: 1, 488: 2, 485: 3, 482: 4, 479: 5, 476: 6, 473: 7, 470: 8, 467: 9, 464: 10, 461: 11, 458: 12, 455: 13, 452: 14, 449: 15, 446: 16, 443: 17, 440: 18, 437: 19, 434: 20, 431: 21, 428: 22, 425: 23, 422: 24, 419: 25, 416: 26, 413: 27, 410: 28, 407: 29, 404: 30, 401: 31, 398: 32, 395: 33, 392: 34, 389: 35, 386: 36, 383: 37, 380: 38, 377: 39, 374: 40, 371: 41, 368: 42, 365: 43, 362: 44, 359: 45, 356: 46, 353: 47, 350: 48, 347: 49, 344: 50, 341: 51, 338: 52, 335: 53, 332: 54, 329: 55, 326: 56, 323: 57, 320: 58, 317: 59, 314: 60, 311: 61, 308: 62, 305: 63, 302: 64, 299: 65, 296: 66, 293: 67, 290: 68, 287: 69, 284: 70, 281: 71, 278: 72, 275: 73, 272: 74, 269: 75, 266: 76, 263: 77, 260: 78, 257: 79, 254: 80, 251: 81, 248: 82, 245: 83, 242: 84, 239: 85, 236: 86, 233: 87, 230: 88, 227: 89, 224: 90, 221: 91, 218: 92, 215: 93, 212: 94, 209: 95, 206: 96, 203: 97, 200: 98, 197: 99, 194: 100, 191: 101, 188: 102, 185: 103, 182: 104, 179: 105, 176: 106, 173: 107, 170: 108, 167: 109, 164: 110, 161: 111, 158: 112, 155: 113, 152: 114, 149: 115, 146: 116, 143: 117, 140: 118, 137: 119, 134: 120, 131: 121, 128: 122, 125: 123, 122: 124, 119: 125, 116: 126, 113: 127, 110: 128, 107: 129, 104: 130, 101: 131, 98: 132, 95: 133, 92: 134, 89: 135, 86: 136, 83: 137, 80: 138, 77: 139, 74: 140, 71: 141, 68: 142, 65: 143, 62: 144, 59: 145, 56: 146, 53: 147, 50: 148, 47: 149, 44: 150, 41: 151, 38: 152, 35: 153, 32: 154, 29: 155, 26: 156, 23: 157}

# %%
#f1.close()
f0.close()
f2.close()

# %%
labels_coordinates = open("labels.py","w+")
labels = []
for i in range(len(SVG_PATHS)):
    f = open("transform.svg","w+")
    f.write('<svg  width="13200" height="10800" xmlns="http://www.w3.org/2000/svg"> \n')
    f.write('    <path d="'+SVG_PATHS[i]+'" stroke="red" fill="red"/> \n')
    f.write('</svg>') 
    f.close() 
    drawing = svg2rlg("transform.svg")
    renderPM.drawToFile(drawing, "labels/13"+str(i)+".png", fmt="PNG") 
    r = Image.open("labels/temp"+str(i)+".png")
    r1=r.resize((388,318), Image.LANCZOS)
    r1.save("labels/r.png", 'PNG')
    r2 = Image.open('labels/r.png')
    r3=Image.new('RGBA', (400, 340), (0, 0, 0, 255))
    r3.paste(r2,(19, 35))
    r3.save("labels/"+str(i)+".png", 'PNG')
    r.close()
    r2.close()
    os.remove("labels/temp"+str(i)+".png")
    os.remove("labels/r.png")
    coordinates = []
    width, height = r3.size
    for x in range(width):
        for y in range(height):
            r,g,b,a = r3.getpixel((x,y))
            if r==255 and g==b==0:
                coordinates.append((x,y))
    labels.append(tuple(coordinates))
    r3.close
    os.remove("labels/"+str(i)+".png")
labels_coordinates.write('labels='+str(labels))

print("--- %s seconds ---" % (time.time() - start_time))

# %%
#download macaque slices
import os
import requests
from PIL import Image, ImageDraw, ImageColor, ImageFilter, ImageFont
dirpath = os.getcwd()
os.makedirs(dirpath+'/slice_numbers')
blank = 'https://scalablebrainatlas.incf.org/templates/CBCetal15/coronal_b0/civm_rhesus_v1_b0_0000.jpg'
#the first slice 23
#the last slice 494
i = 494
for k in range(0, 158):
    print (i)
    temp = blank[0:(len(blank) - (4+len(str(i))))]
    url = temp+str(i)+'.jpg'
    r = requests.get(url)
    with open(str(dirpath+'/slice_numbers'+'/'+str(i)+'.png'),'wb') as f: 
        f.write(r.content)
    i = i-3
# Out:
# 494
# 491
# 488
# 485
# 482
# 479
# 476
# 473
# 470
# 467
# 464
# 461
# 458
# 455
# 452
# 449
# 446
# 443
# 440
# 437
# 434
# 431
# 428
# 425
# 422
# 419
# 416
# 413
# 410
# 407
# 404
# 401
# 398
# 395
# 392
# 389
# 386
# 383
# 380
# 377
# 374
# 371
# 368
# 365
# 362
# 359
# 356
# 353
# 350
# 347
# 344
# 341
# 338
# 335
# 332
# 329
# 326
# 323
# 320
# 317
# 314
# 311
# 308
# 305
# 302
# 299
# 296
# 293
# 290
# 287
# 284
# 281
# 278
# 275
# 272
# 269
# 266
# 263
# 260
# 257
# 254
# 251
# 248
# 245
# 242
# 239
# 236
# 233
# 230
# 227
# 224
# 221
# 218
# 215
# 212
# 209
# 206
# 203
# 200
# 197
# 194
# 191
# 188
# 185
# 182
# 179
# 176
# 173
# 170
# 167
# 164
# 161
# 158
# 155
# 152
# 149
# 146
# 143
# 140
# 137
# 134
# 131
# 128
# 125
# 122
# 119
# 116
# 113
# 110
# 107
# 104
# 101
# 98
# 95
# 92
# 89
# 86
# 83
# 80
# 77
# 74
# 71
# 68
# 65
# 62
# 59
# 56
# 53
# 50
# 47
# 44
# 41
# 38
# 35
# 32
# 29
# 26
# 23
